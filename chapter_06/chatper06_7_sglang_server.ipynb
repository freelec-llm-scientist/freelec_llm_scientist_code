# %% [markdown]
# # 환경설정

# %%
# CUDA Version: 12.6
# !pip install --index-url https://download.pytorch.org/whl/cu124 torch torchvision torchaudio
# !pip install "sglang[all]" transformers huggingface_hub
# !pip install openai
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124, https://packagecloud.io/github/git-lfs/pypi/simple
# ...
# Looking in indexes: https://pypi.org/simple, https://packagecloud.io/github/git-lfs/pypi/simple
# ...
# Looking in indexes: https://pypi.org/simple, https://packagecloud.io/github/git-lfs/pypi/simple
# ...

# %% [markdown]
# # sglang 서버 실행

# %%
# !python -m sglang.launch_server --model-path TinyLlama/TinyLlama-1.1B-Chat-v1.0 --port 30000
# Out:
# /home/sh/anaconda3/envs/sglang/lib/python3.10/site-packages/tvm_ffi/_optional_torch_c_dlpack.py:559: UserWarning: Failed to load torch c dlpack extension: Error building extension 'c_dlpack': [1/2] c++ -MMD -MF main.o.d -DTORCH_EXTENSION_NAME=c_dlpack -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1018\" -I/data/sh/anaconda3/envs/sglang/lib/python3.10/site-packages/tvm_ffi/include -I/data/sh/anaconda3/envs/sglang/lib/python3.10/site-packages/tvm_ffi/include -I/home/sh/anaconda3/envs/sglang/lib/python3.10/site-packages/torch/include -I/home/sh/anaconda3/envs/sglang/lib/python3.10/site-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -isystem /home/sh/anaconda3/envs/sglang/lib/python3.10/site-packages/torch/include -isystem /home/sh/anaconda3/envs/sglang/lib/python3.10/site-packages/torch/include/torch/csrc/api/include -isystem /home/sh/anaconda3/envs/sglang/include/python3.10 -fPIC
# ...
