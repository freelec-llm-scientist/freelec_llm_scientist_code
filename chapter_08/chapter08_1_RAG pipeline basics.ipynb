# %% [markdown]
# # Chapter08
# + 아래 install 및 openai key입력을 진행해주세요
# + 파일이 colab 혹은 폴더 path에 넣어져 있는지 확인해주세요

# %%
! pip install langchain==1.2.14 langchain-openai==1.1.12 langchain-community==0.4.1 langchain-chroma==1.1.0 pymupdf docling rank_bm25
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.2.14)
# Collecting langchain-openai
#   Downloading langchain_openai-1.1.12-py3-none-any.whl.metadata (3.1 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-chroma
#   Downloading langchain_chroma-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting pymupdf
#   Downloading pymupdf-1.27.2.2-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Collecting docling
#   Downloading docling-2.84.0-py3-none-any.whl.metadata (12 kB)
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.2.23)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.1.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.12.3)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (2.30.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (0.12.0)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Downloading langchain_classic-1.0.3-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.48)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.13.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (9.1.4)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.7.23)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Collecting chromadb<2.0.0,>=1.3.5 (from langchain-chroma)
#   Downloading chromadb-1.5.5-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.2 kB)
# Collecting docling-core<3.0.0,>=2.70.0 (from docling-core[chunking]<3.0.0,>=2.70.0->docling)
#   Downloading docling_core-2.71.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting docling-parse<6.0.0,>=5.3.2 (from docling)
#   Downloading docling_parse-5.7.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.9 kB)
# Collecting docling-ibm-models<4,>=3.13.0 (from docling)
#   Downloading docling_ibm_models-3.13.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: torch<3.0.0,>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from docling) (2.10.0+cu128)
# Requirement already satisfied: torchvision<1,>=0 in /usr/local/lib/python3.12/dist-packages (from docling) (0.25.0+cu128)
# Collecting filetype<2.0.0,>=1.2.0 (from docling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting pypdfium2!=4.30.1,<6.0.0,>=4.30.0 (from docling)
#   Downloading pypdfium2-5.6.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: huggingface_hub<2,>=0.23 in /usr/local/lib/python3.12/dist-packages (from docling) (1.8.0)
# Collecting rapidocr<4.0.0,>=3.3 (from docling)
#   Downloading rapidocr-3.7.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.12/dist-packages (from docling) (2026.2.25)
# Requirement already satisfied: rtree<2.0.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from docling) (1.4.1)
# Collecting typer<0.22.0,>=0.12.5 (from docling)
#   Downloading typer-0.21.2-py3-none-any.whl.metadata (16 kB)
# Collecting python-docx<2.0.0,>=1.1.2 (from docling)
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting python-pptx<2.0.0,>=1.0.2 (from docling)
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.12/dist-packages (from docling) (4.13.5)
# Requirement already satisfied: pandas<4.0.0,>=2.1.4 in /usr/local/lib/python3.12/dist-packages (from docling) (2.2.2)
# Collecting marko<3.0.0,>=2.1.2 (from docling)
#   Downloading marko-2.2.2-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from docling) (3.1.5)
# Requirement already satisfied: lxml<7.0.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from docling) (6.0.2)
# Requirement already satisfied: pillow<13.0.0,>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from docling) (11.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from docling) (4.67.3)
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from docling) (1.6.0)
# Collecting pylatexenc<3.0,>=2.10 (from docling)
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 10.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from docling) (1.16.3)
# Requirement already satisfied: accelerate<2,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from docling) (1.13.0)
# Collecting polyfactory>=2.22.2 (from docling)
#   Downloading polyfactory-3.3.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from docling) (0.7.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling) (5.9.5)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling) (0.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (4.15.0)
# Collecting build>=1.0.3 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Downloading build-1.4.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting pybase64>=1.4.1 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Downloading pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.42.0)
# Collecting onnxruntime>=1.14.1 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Downloading onnxruntime-1.24.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.38.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.40.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.2)
# Collecting pypika>=0.48.9 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Downloading pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.80.0)
# Collecting bcrypt>=4.0.1 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Collecting kubernetes>=28.1.0 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Downloading kubernetes-35.0.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11.8)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.26.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting jsonref<2.0.0,>=1.1.0 (from docling-core<3.0.0,>=2.70.0->docling-core[chunking]<3.0.0,>=2.70.0->docling)
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: tabulate<0.11.0,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from docling-core<3.0.0,>=2.70.0->docling-core[chunking]<3.0.0,>=2.70.0->docling) (0.9.0)
# Collecting latex2mathml<4.0.0,>=3.77.0 (from docling-core<3.0.0,>=2.70.0->docling-core[chunking]<3.0.0,>=2.70.0->docling)
#   Downloading latex2mathml-3.79.0-py3-none-any.whl.metadata (15 kB)
# Collecting semchunk<4.0.0,>=2.2.0 (from docling-core[chunking]<3.0.0,>=2.70.0->docling)
#   Downloading semchunk-3.2.5-py3-none-any.whl.metadata (14 kB)
# Collecting tree-sitter<0.27.0,>=0.25.0 (from docling-core[chunking]<3.0.0,>=2.70.0->docling)
#   Downloading tree_sitter-0.25.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10.0 kB)
# Collecting tree-sitter-python>=0.23.6 (from docling-core[chunking]<3.0.0,>=2.70.0->docling)
#   Downloading tree_sitter_python-0.25.0-cp310-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (1.9 kB)
# Collecting tree-sitter-c>=0.23.4 (from docling-core[chunking]<3.0.0,>=2.70.0->docling)
#   Downloading tree_sitter_c-0.24.1-cp310-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting tree-sitter-javascript>=0.23.1 (from docling-core[chunking]<3.0.0,>=2.70.0->docling)
#   Downloading tree_sitter_javascript-0.25.0-cp310-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (2.2 kB)
# Collecting tree-sitter-typescript>=0.23.2 (from docling-core[chunking]<3.0.0,>=2.70.0->docling)
#   Downloading tree_sitter_typescript-0.23.2-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Requirement already satisfied: transformers<6.0.0,>=4.34.0 in /usr/local/lib/python3.12/dist-packages (from docling-core[chunking]<3.0.0,>=2.70.0->docling) (5.0.0)
# Collecting jsonlines<5.0.0,>=3.1.0 (from docling-ibm-models<4,>=3.13.0->docling)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting transformers<6.0.0,>=4.34.0 (from docling-core[chunking]<3.0.0,>=2.70.0->docling)
#   Downloading transformers-5.5.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub<2,>=0.23->docling) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub<2,>=0.23->docling) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub<2,>=0.23->docling) (1.4.2)
# Collecting langchain-text-splitters<2.0.0,>=1.1.1 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.1->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.1->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.1->langchain) (0.3.12)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl<4.0.0,>=3.1.5->docling) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0.0,>=2.1.4->docling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0.0,>=2.1.4->docling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0.0,>=2.1.4->docling) (2025.3)
# Collecting faker>=5.0.0 (from polyfactory>=2.22.2->docling)
#   Downloading faker-40.12.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Collecting XlsxWriter>=0.5.7 (from python-pptx<2.0.0,>=1.0.2->docling)
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Collecting pyclipper>=1.2.0 (from rapidocr<4.0.0,>=3.3->docling)
#   Downloading pyclipper-1.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: opencv_python>=4.5.1.48 in /usr/local/lib/python3.12/dist-packages (from rapidocr<4.0.0,>=3.3->docling) (4.13.0.92)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.12/dist-packages (from rapidocr<4.0.0,>=3.3->docling) (1.17.0)
# Requirement already satisfied: Shapely!=2.0.4,>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from rapidocr<4.0.0,>=3.3->docling) (2.1.2)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from rapidocr<4.0.0,>=3.3->docling) (2.3.0)
# Collecting colorlog (from rapidocr<4.0.0,>=3.3->docling)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->docling) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<3.0.0,>=2.2.2->docling) (1.5.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.22.0,>=0.12.5->docling) (8.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.22.0,>=0.12.5->docling) (0.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.22.0,>=0.12.5->docling) (1.5.4)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.30.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.0.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.2)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.12.19)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.29.6)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.7.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.73.1)
# Collecting opentelemetry-exporter-otlp-proto-common==1.40.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.40.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.40.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Downloading opentelemetry_proto-1.40.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Downloading opentelemetry_sdk-1.40.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Downloading opentelemetry_api-1.40.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-semantic-conventions==0.61b0 (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma)
#   Downloading opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.20.0)
# Collecting mpire[dill] (from semchunk<4.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.70.0->docling)
#   Downloading mpire-2.10.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0.0,>=2.2.2->docling) (1.3.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (15.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0.0,>=2.2.2->docling) (3.0.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->rapidocr<4.0.0,>=3.3->docling) (4.9.3)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.1.2)
# Requirement already satisfied: multiprocess>=0.70.15 in /usr/local/lib/python3.12/dist-packages (from mpire[dill]->semchunk<4.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.70.0->docling) (0.70.16)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.3.1)
# Requirement already satisfied: dill>=0.3.8 in /usr/local/lib/python3.12/dist-packages (from multiprocess>=0.70.15->mpire[dill]->semchunk<4.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.70.0->docling) (0.3.8)
# Downloading langchain_openai-1.1.12-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 11.5 MB/s eta 0:00:00
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 68.0 MB/s eta 0:00:00
# Downloading langchain_chroma-1.1.0-py3-none-any.whl (12 kB)
# Downloading pymupdf-1.27.2.2-cp310-abi3-manylinux_2_28_x86_64.whl (24.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 84.5 MB/s eta 0:00:00
# Downloading docling-2.84.0-py3-none-any.whl (451 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.4/451.4 kB 44.4 MB/s eta 0:00:00
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Downloading chromadb-1.5.5-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.6/21.6 MB 97.0 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading docling_core-2.71.0-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.0/268.0 kB 33.0 MB/s eta 0:00:00
# Downloading docling_ibm_models-3.13.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 12.4 MB/s eta 0:00:00
# Downloading docling_parse-5.7.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 128.8 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading langchain_classic-1.0.3-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 75.3 MB/s eta 0:00:00
# Downloading marko-2.2.2-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 3.3 MB/s eta 0:00:00
# Downloading polyfactory-3.3.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.8 MB/s eta 0:00:00
# Downloading pypdfium2-5.6.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 135.3 MB/s eta 0:00:00
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 30.6 MB/s eta 0:00:00
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 48.8 MB/s eta 0:00:00
# Downloading rapidocr-3.7.0-py3-none-any.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 21.3 MB/s eta 0:00:00
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 8.1 MB/s eta 0:00:00
# Downloading typer-0.21.2-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 6.9 MB/s eta 0:00:00
# Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 30.9 MB/s eta 0:00:00
# Downloading build-1.4.2-py3-none-any.whl (24 kB)
# Downloading faker-40.12.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 108.8 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Downloading kubernetes-35.0.0-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 103.5 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Downloading latex2mathml-3.79.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 10.1 MB/s eta 0:00:00
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 6.6 MB/s eta 0:00:00
# Downloading onnxruntime-1.24.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 102.2 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.40.0-py3-none-any.whl (20 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.40.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.40.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 8.8 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.40.0-py3-none-any.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.0/142.0 kB 18.8 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.40.0-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 8.2 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.6/231.6 kB 27.0 MB/s eta 0:00:00
# Downloading pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.7 MB/s eta 0:00:00
# Downloading pyclipper-1.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (978 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 71.2 MB/s eta 0:00:00
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 7.9 MB/s eta 0:00:00
# Downloading semchunk-3.2.5-py3-none-any.whl (13 kB)
# Downloading transformers-5.5.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 112.3 MB/s eta 0:00:00
# Downloading tree_sitter-0.25.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (635 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 635.4/635.4 kB 60.8 MB/s eta 0:00:00
# Downloading tree_sitter_c-0.24.1-cp310-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 12.9 MB/s eta 0:00:00
# Downloading tree_sitter_javascript-0.25.0-cp310-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 13.3 MB/s eta 0:00:00
# Downloading tree_sitter_python-0.25.0-cp310-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.1/108.1 kB 14.7 MB/s eta 0:00:00
# Downloading tree_sitter_typescript-0.23.2-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (344 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.0/345.0 kB 38.3 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 23.1 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading mpire-2.10.2-py3-none-any.whl (272 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.8/272.8 kB 33.3 MB/s eta 0:00:00
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=6a288ec4f12234dea33835c5c24f462b407e482d40d7b761fb7c71144fc6bf9e
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pypika, pylatexenc, filetype, durationpy, XlsxWriter, tree-sitter-typescript, tree-sitter-python, tree-sitter-javascript, tree-sitter-c, tree-sitter, requests, rank_bm25, python-docx, pyproject_hooks, pypdfium2, pymupdf, pyclipper, pybase64, opentelemetry-proto, mypy-extensions, mpire, marshmallow, marko, latex2mathml, jsonref, jsonlines, faker, colorlog, bcrypt, typing-inspect, rapidocr, python-pptx, polyfactory, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, build, typer, semchunk, opentelemetry-semantic-conventions, kubernetes, dataclasses-json, opentelemetry-sdk, docling-core, opentelemetry-exporter-otlp-proto-grpc, langchain-text-splitters, langchain-openai, docling-parse, transformers, langchain-classic, chromadb, langchain-community, langchain-chroma, docling-ibm-models, docling
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: opentelemetry-proto
#     Found existing installation: opentelemetry-proto 1.38.0
#     Uninstalling opentelemetry-proto-1.38.0:
#       Successfully uninstalled opentelemetry-proto-1.38.0
#   Attempting uninstall: opentelemetry-exporter-otlp-proto-common
#     Found existing installation: opentelemetry-exporter-otlp-proto-common 1.38.0
#     Uninstalling opentelemetry-exporter-otlp-proto-common-1.38.0:
#       Successfully uninstalled opentelemetry-exporter-otlp-proto-common-1.38.0
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.38.0
#     Uninstalling opentelemetry-api-1.38.0:
#       Successfully uninstalled opentelemetry-api-1.38.0
#   Attempting uninstall: typer
#     Found existing installation: typer 0.24.1
#     Uninstalling typer-0.24.1:
#       Successfully uninstalled typer-0.24.1
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.59b0
#     Uninstalling opentelemetry-semantic-conventions-0.59b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.59b0
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.38.0
#     Uninstalling opentelemetry-sdk-1.38.0:
#       Successfully uninstalled opentelemetry-sdk-1.38.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.33.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.40.0 which is incompatible.
# typer-slim 0.24.0 requires typer>=0.24.0, but you have typer 0.21.2 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-exporter-otlp-proto-common==1.38.0, but you have opentelemetry-exporter-otlp-proto-common 1.40.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-proto==1.38.0, but you have opentelemetry-proto 1.40.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-sdk~=1.38.0, but you have opentelemetry-sdk 1.40.0 which is incompatible.
# google-adk 1.28.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.40.0 which is incompatible.
# google-adk 1.28.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.40.0 which is incompatible.
# Successfully installed XlsxWriter-3.2.9 bcrypt-5.0.0 build-1.4.2 chromadb-1.5.5 colorlog-6.10.1 dataclasses-json-0.6.7 docling-2.84.0 docling-core-2.71.0 docling-ibm-models-3.13.0 docling-parse-5.7.0 durationpy-0.10 faker-40.12.0 filetype-1.2.0 jsonlines-4.0.0 jsonref-1.1.0 kubernetes-35.0.0 langchain-chroma-1.1.0 langchain-classic-1.0.3 langchain-community-0.4.1 langchain-openai-1.1.12 langchain-text-splitters-1.1.1 latex2mathml-3.79.0 marko-2.2.2 marshmallow-3.26.2 mpire-2.10.2 mypy-extensions-1.1.0 onnxruntime-1.24.4 opentelemetry-api-1.40.0 opentelemetry-exporter-otlp-proto-common-1.40.0 opentelemetry-exporter-otlp-proto-grpc-1.40.0 opentelemetry-proto-1.40.0 opentelemetry-sdk-1.40.0 opentelemetry-semantic-conventions-0.61b0 polyfactory-3.3.0 pybase64-1.4.3 pyclipper-1.4.0 pylatexenc-2.10 pymupdf-1.27.2.2 pypdfium2-5.6.0 pypika-0.51.1 pyproject_hooks-1.2.0 python-docx-1.2.0 python-pptx-1.0.2 rank_bm25-0.2.2 rapidocr-3.7.0 requests-2.33.1 semchunk-3.2.5 transformers-5.5.0 tree-sitter-0.25.2 tree-sitter-c-0.24.1 tree-sitter-javascript-0.25.0 tree-sitter-python-0.25.0 tree-sitter-typescript-0.23.2 typer-0.21.2 typing-inspect-0.9.0

# %%
import getpass
import os

if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")
# Out:
# Enter your OpenAI API key: ··········

# %% [markdown]
# ## 8.2.1 랭체인을 이용한 API 호출

# %%
from langchain_openai import ChatOpenAI
import os

try:
    llm = ChatOpenAI(
        model="gpt-4o", # 최신 모델 사용 권장
        temperature=0.2, # 답변의 창의성을 0.0~1.0 사이에서 조절 (낮을수록 보수적/사실적)
        openai_api_key=os.getenv("OPENAI_API_KEY")
    )
    response = llm.invoke("RAG란 무엇인가요?")
    print(response.content)
except Exception as e:
    print(f"오류가 발생했습니다. API Key값과 모델명을 확인해주세요: {e}")
# Out:
# RAG는 "Retrieval-Augmented Generation"의 약자로, 자연어 처리 분야에서 정보를 생성하는 데 있어 검색을 활용하는 방법론을 의미합니다. RAG는 대규모 언어 모델과 정보 검색 시스템을 결합하여, 질문에 대한 더 정확하고 관련성 높은 답변을 생성하는 데 사용됩니다.
#
# 이 방법은 두 가지 주요 단계로 이루어져 있습니다. 첫 번째 단계는 질문이나 요청과 관련된 정보를 외부 데이터베이스나 문서 집합에서 검색하는 것입니다. 두 번째 단계는 검색된 정보를 바탕으로 언어 생성 모델이 최종 답변을 생성하는 것입니다. 이를 통해 RAG는 단순히 훈련 데이터에 의존하는 것보다 더 풍부하고 정확한 정보를 제공할 수 있습니다.

# %% [markdown]
# ## 8.2.2 PDF 로더

# %%
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
import os

# 예제 파일 경로 설정 (실제 PDF 파일이 있어야 합니다.)
PDF_FILE_PATH = "content/한국은행 2024년 연차보고서.pdf"

if not os.path.exists(PDF_FILE_PATH):
    print(f"⚠️ 경고: {PDF_FILE_PATH} 파일이 없어 로딩을 건너뜁니다. 파일을 준비해주세요.")
else:
    # 1. 문서 로딩 (Document Loading)
    loader = PyMuPDFLoader(PDF_FILE_PATH)
    # .load() 메서드는 각 페이지를 하나의 Document 객체 리스트로 반환합니다.
    docs = loader.load()

    print(f"✅ 문서 로드 성공! 총 {len(docs)} 페이지가 로드되었습니다.")
    print(f"첫 페이지 메타데이터: {docs[0].metadata}")

    # 2. 문서 분할 (Text Splitting) 준비
    # RecursiveCharacterTextSplitter를 사용하여 청크를 나눕니다.
    # 청킹 크기와 오버랩은 LLM의 토큰 윈도우와 문서의 성격에 따라 조정이 필요합니다.
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=1000,
        chunk_overlap=200 # 이전 청크와의 중첩을 통해 문맥 손실 방지
    )

    # 로드된 Document 객체 리스트를 청크로 분할
    chunks = splitter.split_documents(docs)

    print(f"✅ 청킹 완료. 총 {len(chunks)}개의 청크가 생성되었습니다.")
    print(f"첫 번째 청크 내용 일부:\n{chunks[0].page_content[:200]}...")
# Out:
# ✅ 문서 로드 성공! 총 154 페이지가 로드되었습니다.
# 첫 페이지 메타데이터: {'producer': 'Codel PDF Imposition 1.0', 'creator': 'Codel PDF Imposition 1.0', 'creationdate': 'March 25, 2025 17:16', 'source': '한국은행 2024년 연차보고서.pdf', 'file_path': '한국은행 2024년 연차보고서.pdf', 'total_pages': 154, 'format': 'PDF 1.7', 'title': '¡á ÃÖÁ¾ÇÕº»_f_188x257-È®ÀÎ¿ë.PDF', 'author': 'INSUNG DATA INC.', 'subject': 'CoreImposition PDF 1.0 Output', 'keywords': '', 'moddate': 'March 25, 2025 17:16', 'trapped': '', 'modDate': 'March 25, 2025 17:16', 'creationDate': 'March 25, 2025 17:16', 'page': 0}
# ✅ 청킹 완료. 총 245개의 청크가 생성되었습니다.
# 첫 번째 청크 내용 일부:
# ISSN 1975-4922
# 2024
# 연차보고서
# 2025. 3...

# %% [markdown]
# ## 8.2.3 청킹 전략

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 텍스트 예시: 논리적 문단 구분과 문장 마침표가 포함됨
text = """
## 2.1 국내 기준금리 동향
2024년 상반기 한국은행은 기준금리를 3.5%로 유지했습니다. 이는 물가 안정 추세를 반영한 결과입니다.
하지만 미국 연준의 긴축 기조가 예상보다 강하게 이어질 경우, 하반기에는 금융 시장의 변동성이 확대될 수 있으며, 추가 인상 가능성이 제기됩니다.
"""

# 청킹 설정: 토큰 크기 100, 오버랩 20
splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20,
    # 구분자 우선순위: 문단(두 줄바꿈) -> 문장(한 줄바꿈) -> 마침표 -> 공백
    separators=["\n\n", "\n", ".", " ", ""]
)

chunks = splitter.split_text(text)
print(f"--- RecursiveCharacterTextSplitter 실행 결과 (총 {len(chunks)}개 청크) ---")
for i, c in enumerate(chunks):
    print(f"\n[Chunk {i+1}] (길이: {len(c)})")
    print(c.strip())
# Out:
# --- RecursiveCharacterTextSplitter 실행 결과 (총 2개 청크) ---
#
# [Chunk 1] (길이: 77)
# ## 2.1 국내 기준금리 동향
# 2024년 상반기 한국은행은 기준금리를 3.5%로 유지했습니다. 이는 물가 안정 추세를 반영한 결과입니다.
#
# [Chunk 2] (길이: 81)
# 하지만 미국 연준의 긴축 기조가 예상보다 강하게 이어질 경우, 하반기에는 금융 시장의 변동성이 확대될 수 있으며, 추가 인상 가능성이 제기됩니다.

# %%
from docling.document_converter import DocumentConverter
from docling_core.transforms.chunker.hierarchical_chunker import HierarchicalChunker
from docling_core.transforms.chunker.hybrid_chunker import HybridChunker

# 문서 경로 설정 (실제 파일 경로로 수정 필요)
pdf_path = "content/한국은행 2025년 9월중 금융시장 동향.pdf"

# 문서 변환
print("\n[1단계] 문서 변환 중...")
converter = DocumentConverter()
result = converter.convert(source=pdf_path)
doc = result.document

# 문서가 제대로 변환되었는지 확인
if doc is None:
    raise ValueError("문서 변환에 실패했습니다.")

print(f"문서 변환 완료. 페이지 수: {len(doc.pages) if hasattr(doc, 'pages') else 'N/A'}")

# 구조 기반 청킹
print("\n[2단계] 청킹 중...")
hc = HierarchicalChunker()
chunks = list(hc.chunk(dl_doc=doc))
print(f"청크 수: {len(chunks)}")

# 결과 출력 (선택사항)
print("\n=== 청크 샘플 (처음 3개) ===")
for i, chunk in enumerate(chunks[:3], 1):
    print(f"\n[청크 {i}]")
    print(f"텍스트: {chunk.text[:200]}...")  # 처음 200자만 출력
    if hasattr(chunk, 'meta'):
        print(f"메타데이터: {chunk.meta}")
# Out:
# [1단계] 문서 변환 중...
# [INFO] 2026-04-05 14:30:38,558 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-04-05 14:30:38,575 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-04-05 14:30:38,576 [RapidOCR] main.py:53: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-04-05 14:30:38,695 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-04-05 14:30:38,699 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2026-04-05 14:30:38,699 [RapidOCR] main.py:53: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2026-04-05 14:30:38,748 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-04-05 14:30:38,778 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.onnx
# [INFO] 2026-04-05 14:30:38,779 [RapidOCR] main.py:53: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.onnx
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/770 [00:00<?, ?it/s]
# 문서 변환 완료. 페이지 수: 7
#
# [2단계] 청킹 중...
# 청크 수: 35
#
# === 청크 샘플 (처음 3개) ===
#
# [청크 1]
# 텍스트: 이자료는 10월 17일(금) 조간부터 취급하여 주십시오. 단, 통신/방송/인터넷 매체는 10월 16일(목) 12:00 이후부터 취급 가능...
# 메타데이터: schema_name='docling_core.transforms.chunker.DocMeta' version='1.0.0' doc_items=[TextItem(self_ref='#/texts/1', parent=RefItem(cref='#/body'), children=[], content_layer=<ContentLayer.BODY: 'body'>, meta=None, label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=1, bbox=BoundingBox(l=310.031975, t=740.251064452, r=523.67123102, b=697.3489904, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 76))], source=[], comments=[], orig='이자료는 10월 17일(금) 조간부터 취급하여 주십시오. 단, 통신/방송/인터넷 매체는 10월 16일(목) 12:00 이후부터 취급 가능', text='이자료는 10월 17일(금) 조간부터 취급하여 주십시오. 단, 통신/방송/인터넷 매체는 10월 16일(목) 12:00 이후부터 취급 가능', formatting=None, hyperlink=None)] headings=None captions=None origin=DocumentOrigin(mimetype='application/pdf', binary_hash=10184324208935375502, filename='한국은행 2025년 9월중 금융시장 동향.pdf', uri=None)
#
# [청크 2]
# 텍스트: 제 목 : 2025년 9월중 금융시장 동향...
# 메타데이터: schema_name='docling_core.transforms.chunker.DocMeta' version='1.0.0' doc_items=[TextItem(self_ref='#/texts/2', parent=RefItem(cref='#/groups/0'), children=[], content_layer=<ContentLayer.BODY: 'body'>, meta=None, label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=1, bbox=BoundingBox(l=84.314305, t=675.972392023, r=358.125310325, b=660.0457576, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 23))], source=[], comments=[], orig='제 목 : 2025년 9월중 금융시장 동향', text='제 목 : 2025년 9월중 금융시장 동향', formatting=None, hyperlink=None)] headings=None captions=None origin=DocumentOrigin(mimetype='application/pdf', binary_hash=10184324208935375502, filename='한국은행 2025년 9월중 금융시장 동향.pdf', uri=None)
#
# [청크 3]
# 텍스트: - ▣ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융 안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - ▣ 코스피 는 반도체 업황 호조 및 자본시장 제도 개선에 대한 기대 , 외국인의 대규모 순매수 등으로 사상 최고치를 경신하며 큰 폭 상승
# - ▣ 9 월 은행대출 은 가계대출 (25.8 월 +4.1 조원 → 9 월 +2...
# 메타데이터: schema_name='docling_core.transforms.chunker.DocMeta' version='1.0.0' doc_items=[ListItem(self_ref='#/texts/3', parent=RefItem(cref='#/groups/1'), children=[], content_layer=<ContentLayer.BODY: 'body'>, meta=None, label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=1, bbox=BoundingBox(l=73.64009, t=628.232525, r=523.15647, b=590.439867073, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 74))], source=[], comments=[], orig='▣ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융 안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승', text='▣ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융 안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승', formatting=None, hyperlink=None, enumerated=False, marker=''), ListItem(self_ref='#/texts/4', parent=RefItem(cref='#/groups/1'), children=[], content_layer=<ContentLayer.BODY: 'body'>, meta=None, label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=1, bbox=BoundingBox(l=77.118205, t=565.3013, r=523.03845396, b=527.5086420729999, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 76))], source=[], comments=[], orig='▣ 코스피 는 반도체 업황 호조 및 자본시장 제도 개선에 대한 기대 , 외국인의 대규모 순매수 등으로 사상 최고치를 경신하며 큰 폭 상승', text='▣ 코스피 는 반도체 업황 호조 및 자본시장 제도 개선에 대한 기대 , 외국인의 대규모 순매수 등으로 사상 최고치를 경신하며 큰 폭 상승', formatting=None, hyperlink=None, enumerated=False, marker=''), ListItem(self_ref='#/texts/5', parent=RefItem(cref='#/groups/1'), children=[], content_layer=<ContentLayer.BODY: 'body'>, meta=None, label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=1, bbox=BoundingBox(l=77.118205, t=502.370075, r=522.4371118634999, b=464.577417073, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 96))], source=[], comments=[], orig='▣ 9 월 은행대출 은 가계대출 (25.8 월 +4.1 조원 → 9 월 +2.0 조원 ) 과 기업대출 (+8.4 조원 → +5.3 조원 ) 모두 전월에 비해 증가규모가 축소', text='▣ 9 월 은행대출 은 가계대출 (25.8 월 +4.1 조원 → 9 월 +2.0 조원 ) 과 기업대출 (+8.4 조원 → +5.3 조원 ) 모두 전월에 비해 증가규모가 축소', formatting=None, hyperlink=None, enumerated=False, marker=''), ListItem(self_ref='#/texts/6', parent=RefItem(cref='#/groups/1'), children=[], content_layer=<ContentLayer.BODY: 'body'>, meta=None, label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=1, bbox=BoundingBox(l=77.118205, t=443.874003, r=523.15647, b=406.081345073, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 102))], source=[], comments=[], orig='▣ 9 월 금융기관 수신은 은행 (25.8 월 +32.9 조원 → 9 월 +31.9 조원 ) 이 큰 폭 증가하였으나 , 자산운용사 (+15.6 조원 → -4.2 조원 ) 는 감소 전환', text='▣ 9 월 금융기관 수신은 은행 (25.8 월 +32.9 조원 → 9 월 +31.9 조원 ) 이 큰 폭 증가하였으나 , 자산운용사 (+15.6 조원 → -4.2 조원 ) 는 감소 전환', formatting=None, hyperlink=None, enumerated=False, marker='')] headings=None captions=None origin=DocumentOrigin(mimetype='application/pdf', binary_hash=10184324208935375502, filename='한국은행 2025년 9월중 금융시장 동향.pdf', uri=None)

# %% [markdown]
# ## 8.2.4 벡터 데이터베이스

# %%
from docling.document_converter import DocumentConverter
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document as LangChainDocument
import os

print("\n[3단계] LangChain Document 형식으로 변환 중...")

langchain_docs = []
for i, chunk in enumerate(chunks):
    # 메타데이터 추출
    metadata = {
        "chunk_id": i,
        "source": pdf_path,
        "char_count": len(chunk.text)
    }

    # 제목 정보 추출
    if hasattr(chunk, 'meta'):
        # 제목/헤딩 정보
        if hasattr(chunk.meta, 'headings') and chunk.meta.headings:
            headings = [h.text for h in chunk.meta.headings if hasattr(h, 'text')]
            metadata['section'] = " > ".join(headings) if headings else "본문"
        else:
            metadata['section'] = "본문"

        # 캡션 정보
        if hasattr(chunk.meta, 'captions') and chunk.meta.captions:
            captions = [c.text for c in chunk.meta.captions if hasattr(c, 'text')]
            if captions:
                metadata['caption'] = " | ".join(captions)

        # 문서 항목 타입
        if hasattr(chunk.meta, 'doc_items') and chunk.meta.doc_items:
            item_types = []
            for item in chunk.meta.doc_items:
                if hasattr(item, 'label'):
                    label = str(item.label).split('.')[-1]
                    item_types.append(label)
            if item_types:
                metadata['content_type'] = ', '.join(set(item_types))

        # 페이지 번호
        if hasattr(chunk.meta, 'doc_items') and chunk.meta.doc_items:
            for item in chunk.meta.doc_items:
                if hasattr(item, 'prov') and item.prov:
                    for prov in item.prov:
                        if hasattr(prov, 'page_no'):
                            metadata['page'] = prov.page_no
                            break
                    if 'page' in metadata:
                        break

    # LangChain Document 생성
    langchain_doc = LangChainDocument(
        page_content=chunk.text,
        metadata=metadata
    )
    langchain_docs.append(langchain_doc)

print(f"✅ {len(langchain_docs)}개 LangChain Document 생성")

# 메타데이터 샘플 출력
print("\n📋 메타데이터 샘플 (처음 3개):")
for i, doc in enumerate(langchain_docs[:3], 1):
    print(f"\n[Document {i}]")
    print(f"  섹션: {doc.metadata.get('section', 'N/A')}")
    print(f"  페이지: {doc.metadata.get('page', 'N/A')}")
    print(f"  타입: {doc.metadata.get('content_type', 'N/A')}")
    print(f"  텍스트: {doc.page_content[:100]}...")

# ========================================
# 3. OpenAI 임베딩 모델 설정
# ========================================
print("\n[4단계] OpenAI 임베딩 모델 설정 중...")

if "OPENAI_API_KEY" not in os.environ:
    raise ValueError("OPENAI_API_KEY 환경변수를 설정해주세요!")

# OpenAI 임베딩 모델
# text-embedding-3-small: 저렴하고 빠름 (추천)
# text-embedding-3-large: 더 높은 성능
# text-embedding-ada-002: 구버전 (레거시)
embedding_model = OpenAIEmbeddings(
    model="text-embedding-3-small",  # 또는 "text-embedding-3-large"
    # dimensions=1536,  # 차원 축소 가능 (선택사항)
)

print("✅ OpenAI 임베딩 모델 설정 완료")
print("   모델: text-embedding-3-small")

# ========================================
# 4. 벡터 데이터베이스 생성
# ========================================
print("\n[5단계] Chroma 벡터 DB 생성 중...")

db = Chroma.from_documents(
    documents=langchain_docs,
    embedding=embedding_model,
    collection_name="korean_financial_docs",
    persist_directory="./chroma_db"  # 영구 저장
)

print(f"✅ 벡터 DB 생성 완료: {len(langchain_docs)}개 문서 저장")

# ========================================
# 5. 검색 테스트
# ========================================
print("\n" + "=" * 70)
print("🔍 검색 테스트")
print("=" * 70)

test_queries = [
    "한국은행의 금리 인상 배경",
    "코스피 상승 이유",
    "9월 은행 대출 증가 현황"
]

for query in test_queries:
    print(f"\n📌 질문: {query}")
    print("-" * 70)

    # 유사도 검색 (top 3)
    results = db.similarity_search(query, k=3)

    for i, result in enumerate(results, 1):
        print(f"\n[결과 {i}]")
        print(f"  섹션: {result.metadata.get('section', 'N/A')}")
        print(f"  페이지: {result.metadata.get('page', 'N/A')}")
        print(f"  타입: {result.metadata.get('content_type', 'N/A')}")
        print(f"  내용: {result.page_content[:200]}...")

    print("\n" + "=" * 70)

# ========================================
# 6. 고급 검색 (점수 포함)
# ========================================
print("\n🎯 유사도 점수 포함 검색")
print("=" * 70)

query = "금융시장 동향"
results_with_scores = db.similarity_search_with_score(query, k=3)

print(f"\n📌 질문: {query}\n")
for i, (doc, score) in enumerate(results_with_scores, 1):
    print(f"[결과 {i}] 유사도: {1 - score:.4f}")  # 거리를 유사도로 변환
    print(f"  섹션: {doc.metadata.get('section', 'N/A')}")
    print(f"  내용: {doc.page_content[:150]}...")
    print()

print("=" * 70)
print("✅ RAG 파이프라인 구축 완료!")
print("\n💡 사용 방법:")
print("   db.similarity_search(query, k=3)  # 유사 문서 검색")
print("   db.similarity_search_with_score(query, k=3)  # 점수 포함")
print("   db.as_retriever(search_kwargs={'k': 5})  # Retriever로 사용")
# Out:
# [3단계] LangChain Document 형식으로 변환 중...
# ✅ 35개 LangChain Document 생성
#
# 📋 메타데이터 샘플 (처음 3개):
#
# [Document 1]
#   섹션: 본문
#   페이지: 1
#   타입: text
#   텍스트: 이자료는 10월 17일(금) 조간부터 취급하여 주십시오. 단, 통신/방송/인터넷 매체는 10월 16일(목) 12:00 이후부터 취급 가능...
#
# [Document 2]
#   섹션: 본문
#   페이지: 1
#   타입: text
#   텍스트: 제 목 : 2025년 9월중 금융시장 동향...
#
# [Document 3]
#   섹션: 본문
#   페이지: 1
#   타입: list_item
#   텍스트: - ▣ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융 안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - ▣ 코스피 는 반도체 업황 호조 및 자...
#
# [4단계] OpenAI 임베딩 모델 설정 중...
# ✅ OpenAI 임베딩 모델 설정 완료
#    모델: text-embedding-3-small
#
# [5단계] Chroma 벡터 DB 생성 중...
# /tmp/ipykernel_7316/717681201.py:28: DeprecationWarning: deprecated
#   if hasattr(chunk.meta, 'captions') and chunk.meta.captions:
# ✅ 벡터 DB 생성 완료: 35개 문서 저장
#
# ======================================================================
# 🔍 검색 테스트
# ======================================================================
#
# 📌 질문: 한국은행의 금리 인상 배경
# ----------------------------------------------------------------------
#
# [결과 1]
#   섹션: 본문
#   페이지: 1
#   타입: text
#   내용: '한국은행 보도자료는 인터넷(http://www.bok.or.kr)에도 수록되어 있습니다.'...
#
# [결과 2]
#   섹션: 본문
#   페이지: 2
#   타입: list_item
#   내용: - □ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - □ 단기시장금리 는 기준금리 인하 기대 약화 , 발행물량 감소 등의 영향 이 엇갈리며 대체로 보합세 *
# * 다만 , 은행채는 MMF 의 투자수요 부진 등으로 소폭 상승
# - □ 코스피 는 반도체 업황 호조 및 자본시장 제...
#
# [결과 3]
#   섹션: 본문
#   페이지: 1
#   타입: list_item
#   내용: - ▣ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융 안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - ▣ 코스피 는 반도체 업황 호조 및 자본시장 제도 개선에 대한 기대 , 외국인의 대규모 순매수 등으로 사상 최고치를 경신하며 큰 폭 상승
# - ▣ 9 월 은행대출 은 가계대출 (25.8 월 +4.1 조원 → 9 월 +2...
#
# ======================================================================
#
# 📌 질문: 코스피 상승 이유
# ----------------------------------------------------------------------
#
# [결과 1]
#   섹션: 본문
#   페이지: 2
#   타입: list_item
#   내용: - □ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - □ 단기시장금리 는 기준금리 인하 기대 약화 , 발행물량 감소 등의 영향 이 엇갈리며 대체로 보합세 *
# * 다만 , 은행채는 MMF 의 투자수요 부진 등으로 소폭 상승
# - □ 코스피 는 반도체 업황 호조 및 자본시장 제...
#
# [결과 2]
#   섹션: 본문
#   페이지: 1
#   타입: list_item
#   내용: - ▣ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융 안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - ▣ 코스피 는 반도체 업황 호조 및 자본시장 제도 개선에 대한 기대 , 외국인의 대규모 순매수 등으로 사상 최고치를 경신하며 큰 폭 상승
# - ▣ 9 월 은행대출 은 가계대출 (25.8 월 +4.1 조원 → 9 월 +2...
#
# [결과 3]
#   섹션: 본문
#   페이지: 2
#   타입: table
#   내용: ￭ 국고채 (3 년 ), 23.12 월 = 3.15. ￭ 국고채 (3 년 ), 24.12 월 = 2.60. ￭ 국고채 (3 년 ), 25.7 월 = 2.46. ￭ 국고채 (3 년 ), 8 월 (A) = 2.43. ￭ 국고채 (3 년 ), 9 월 = 2.58. ￭ 국고채 (3 년 ), 10.15 일 (B) = 2.52. ￭ 국고채 (3 년 ), B -A = ...
#
# ======================================================================
#
# 📌 질문: 9월 은행 대출 증가 현황
# ----------------------------------------------------------------------
#
# [결과 1]
#   섹션: 본문
#   페이지: 1
#   타입: list_item
#   내용: - ▣ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융 안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - ▣ 코스피 는 반도체 업황 호조 및 자본시장 제도 개선에 대한 기대 , 외국인의 대규모 순매수 등으로 사상 최고치를 경신하며 큰 폭 상승
# - ▣ 9 월 은행대출 은 가계대출 (25.8 월 +4.1 조원 → 9 월 +2...
#
# [결과 2]
#   섹션: 본문
#   페이지: 3
#   타입: list_item
#   내용: - □ 9 월 은행 가계대출 은 전월에 비해 증가규모가 상당폭 축소 (25.8 월 +4.1 조원 → 9 월 +2.0 조원 ; 24.9 월 +5.6 조원 )
# - o 주택담보대출 (+3.8 조원 → +2.5 조원 ) 은 6.27 대책의 영향이 지속된 데다 계절적 요인으로 전세자금 수요도 감소하면서 증가폭 축소
# - o 기타대출 (+0.3 조원 → -0.5 조원 ...
#
# [결과 3]
#   섹션: 본문
#   페이지: 4
#   타입: list_item
#   내용: - □ 9 월 은행 기업대출 은 계절적 요인 등으로 전월에 비해 증가규모가 축소 (25.8 월 +8.4 조원 → 9 월 +5.3 조원 ; 24.9 월 +4.3 조원 )
# - o 중소기업대출 (+4.5 조원 → +4.0 조원 ) 은 부실채권 매 · 상각에도 주요 은행 들의 대출영업 확대 , 추석자금 수요 등으로 전월과 비슷한 규모로 증가
# - o 대기업대출 (+...
#
# ======================================================================
#
# 🎯 유사도 점수 포함 검색
# ======================================================================
#
# 📌 질문: 금융시장 동향
#
# [결과 1] 유사도: 0.4621
#   섹션: 본문
#   내용: 제 목 : 2025년 9월중 금융시장 동향...
#
# [결과 2] 유사도: -0.2064
#   섹션: 본문
#   내용: - □ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - □ 단기시장금리 는 기준금리 인하 기대 약화 , 발행물량 감소 등의 영향 이 엇갈리며 대체로 보합세 *
# * 다만 , 은행채는 MM...
#
# [결과 3] 유사도: -0.2251
#   섹션: 본문
#   내용: - □ 9 월 은행 가계대출 은 전월에 비해 증가규모가 상당폭 축소 (25.8 월 +4.1 조원 → 9 월 +2.0 조원 ; 24.9 월 +5.6 조원 )
# - o 주택담보대출 (+3.8 조원 → +2.5 조원 ) 은 6.27 대책의 영향이 지속된 데다 계절적 요인으로 ...
#
# ======================================================================
# ✅ RAG 파이프라인 구축 완료!
#
# 💡 사용 방법:
#    db.similarity_search(query, k=3)  # 유사 문서 검색
#    db.similarity_search_with_score(query, k=3)  # 점수 포함
#    db.as_retriever(search_kwargs={'k': 5})  # Retriever로 사용

# %% [markdown]
# ## 8.3.1 Multi-vector retrieval

# %%
# 1) 원본 텍스트용 DB
text_db = Chroma.from_documents(
    documents=langchain_docs,
    embedding=embedding_model,
    collection_name="text_embeddings",
    persist_directory="./chroma_db"
)
print(f"✅ 텍스트 DB: {len(langchain_docs)}개 저장")

# 2) 요약본용 DB
summary_docs = []
for doc in langchain_docs:
    # 요약 생성 (예시: 처음 200자)
    summary = doc.page_content[:200] + "..."
    summary_doc = LangChainDocument(
        page_content=summary,
        metadata=doc.metadata
    )
    summary_docs.append(summary_doc)

summary_db = Chroma.from_documents(
    documents=summary_docs,
    embedding=embedding_model,
    collection_name="summary_embeddings",
    persist_directory="./chroma_db"
)
print(f"✅ 요약 DB: {len(summary_docs)}개 저장")

# 3) 키워드용 DB
keyword_docs = []
for doc in langchain_docs:
    # 키워드 추출 (예시: 섹션명 + 타입)
    keywords = f"{doc.metadata.get('section', '')} {doc.metadata.get('content_type', '')}"
    keyword_doc = LangChainDocument(
        page_content=keywords,
        metadata=doc.metadata
    )
    keyword_docs.append(keyword_doc)

keyword_db = Chroma.from_documents(
    documents=keyword_docs,
    embedding=embedding_model,
    collection_name="keyword_embeddings",
    persist_directory="./chroma_db"
)
print(f"✅ 키워드 DB: {len(keyword_docs)}개 저장")

# ========================================
# EnsembleRetriever로 통합
# ========================================
from langchain_classic.retrievers import EnsembleRetriever

text_retriever = text_db.as_retriever(search_kwargs={"k": 5})
summary_retriever = summary_db.as_retriever(search_kwargs={"k": 5})
keyword_retriever = keyword_db.as_retriever(search_kwargs={"k": 5})

ensemble_retriever = EnsembleRetriever(
    retrievers=[text_retriever, summary_retriever, keyword_retriever],
    weights=[0.5, 0.3, 0.2]
)

print("✅ Multi-vector RAG 파이프라인 완료!")
# Out:
# ✅ 텍스트 DB: 35개 저장
# ✅ 요약 DB: 35개 저장
# ✅ 키워드 DB: 35개 저장
# ✅ Multi-vector RAG 파이프라인 완료!

# %%
# ========================================
# 검색 테스트
# ========================================
print("\n🔍 Multi-vector 검색 테스트")
query = "한국은행의 금리 인상 배경"
results = ensemble_retriever.invoke(query)

for i, result in enumerate(results[:3], 1):
    print(f"\n[결과 {i}]")
    print(f"  섹션: {result.metadata.get('section', 'N/A')}")
    print(f"  내용: {result.page_content[:150]}...")
# Out:
# 🔍 Multi-vector 검색 테스트
#
# [결과 1]
#   섹션: 본문
#   내용: 본문 text...
#
# [결과 2]
#   섹션: 본문
#   내용: '한국은행 보도자료는 인터넷(http://www.bok.or.kr)에도 수록되어 있습니다.'...
#
# [결과 3]
#   섹션: 본문
#   내용: - □ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - □ 단기시장금리 는 기준금리 인하 기대 약화 , 발행물량 감소 등의 영향 이 엇갈리며 대체로 보합세 *
# * 다만 , 은행채는 MM...

# %% [markdown]
# ## 8.3.2 BM25 와 하이브리드 검색기

# %%
keyword_docs
# Out:
# [Document(metadata={'chunk_id': 0, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 76, 'section': '본문', 'content_type': 'text', 'page': 1}, page_content='본문 text'),
#  Document(metadata={'chunk_id': 1, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 23, 'section': '본문', 'content_type': 'text', 'page': 1}, page_content='본문 text'),
#  Document(metadata={'chunk_id': 2, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 359, 'section': '본문', 'content_type': 'list_item', 'page': 1}, page_content='본문 list_item'),
#  Document(metadata={'chunk_id': 3, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 19, 'section': '본문', 'content_type': 'text', 'page': 1}, page_content='본문 text'),
#  Document(metadata={'chunk_id': 4, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 80, 'section': '본문', 'content_type': 'list_item', 'page': 1}, page_content='본문 list_item'),
#  Document(metadata={'chunk_id': 5, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 45, 'section': '본문', 'content_type': 'text', 'page': 1}, page_content='본문 text'),
#  Document(metadata={'chunk_id': 6, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 27, 'section': '본문', 'content_type': 'text', 'page': 1}, page_content='본문 text'),
#  Document(metadata={'chunk_id': 7, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 30, 'section': '본문', 'content_type': 'text', 'page': 1}, page_content='본문 text'),
#  Document(metadata={'chunk_id': 8, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 51, 'section': '본문', 'content_type': 'text', 'page': 1}, page_content='본문 text'),
#  Document(metadata={'chunk_id': 9, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 306, 'section': '본문', 'content_type': 'list_item', 'page': 2}, page_content='본문 list_item'),
#  Document(metadata={'chunk_id': 10, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 2867, 'section': '본문', 'content_type': 'table', 'page': 2}, page_content='본문 table'),
#  Document(metadata={'chunk_id': 11, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 95, 'section': '본문', 'content_type': 'list_item', 'page': 2}, page_content='본문 list_item'),
#  Document(metadata={'chunk_id': 12, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 15, 'section': '본문', 'content_type': 'text', 'page': 2}, page_content='본문 text'),
#  Document(metadata={'chunk_id': 13, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 258, 'section': '본문', 'content_type': 'list_item', 'page': 3}, page_content='본문 list_item'),
#  Document(metadata={'chunk_id': 14, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 67, 'section': '본문', 'content_type': 'text', 'page': 3}, page_content='본문 text'),
#  Document(metadata={'chunk_id': 15, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 995, 'section': '본문', 'content_type': 'table', 'page': 3}, page_content='본문 table'),
#  Document(metadata={'chunk_id': 16, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 18, 'section': '본문', 'content_type': 'text', 'page': 3}, page_content='본문 text'),
#  Document(metadata={'chunk_id': 17, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 887, 'section': '본문', 'content_type': 'table', 'page': 3}, page_content='본문 table'),
#  Document(metadata={'chunk_id': 18, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 455, 'section': '본문', 'content_type': 'list_item', 'page': 4}, page_content='본문 list_item'),
#  Document(metadata={'chunk_id': 19, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 18, 'section': '본문', 'content_type': 'text', 'page': 4}, page_content='본문 text'),
#  Document(metadata={'chunk_id': 20, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 2308, 'section': '본문', 'content_type': 'table', 'page': 4}, page_content='본문 table'),
#  Document(metadata={'chunk_id': 21, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 134, 'section': '본문', 'content_type': 'list_item', 'page': 4}, page_content='본문 list_item'),
#  Document(metadata={'chunk_id': 22, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 502, 'section': '본문', 'content_type': 'list_item', 'page': 5}, page_content='본문 list_item'),
#  Document(metadata={'chunk_id': 23, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 18, 'section': '본문', 'content_type': 'text', 'page': 5}, page_content='본문 text'),
#  Document(metadata={'chunk_id': 24, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 3120, 'section': '본문', 'content_type': 'table', 'page': 5}, page_content='본문 table'),
#  Document(metadata={'chunk_id': 25, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 28, 'section': '본문', 'content_type': 'text', 'page': 5}, page_content='본문 text'),
#  Document(metadata={'chunk_id': 26, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 14, 'section': '본문', 'content_type': 'footnote', 'page': 5}, page_content='본문 footnote'),
#  Document(metadata={'chunk_id': 27, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 13, 'section': '본문', 'content_type': 'footnote', 'page': 5}, page_content='본문 footnote'),
#  Document(metadata={'chunk_id': 28, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 35, 'section': '본문', 'content_type': 'footnote', 'page': 5}, page_content='본문 footnote'),
#  Document(metadata={'chunk_id': 29, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 18, 'section': '본문', 'content_type': 'text', 'page': 6}, page_content='본문 text'),
#  Document(metadata={'chunk_id': 30, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 1645, 'section': '본문', 'content_type': 'table', 'page': 6}, page_content='본문 table'),
#  Document(metadata={'chunk_id': 31, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 295, 'section': '본문', 'content_type': 'list_item', 'page': 6}, page_content='본문 list_item'),
#  Document(metadata={'chunk_id': 32, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 18, 'section': '본문', 'content_type': 'text', 'page': 7}, page_content='본문 text'),
#  Document(metadata={'chunk_id': 33, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 3173, 'section': '본문', 'content_type': 'table', 'page': 7}, page_content='본문 table'),
#  Document(metadata={'chunk_id': 34, 'source': '/content/한국은행 2025년 9월중 금융시장 동향.pdf', 'char_count': 89, 'section': '본문', 'content_type': 'list_item', 'page': 7}, page_content='본문 list_item')]

# %%
from langchain_community.retrievers import BM25Retriever

bm25_retriever = BM25Retriever.from_documents(keyword_docs)
bm25_retriever.k = 3  # 상위 3개 결과 반환

query_bm25 = "9월 은행 가계대출"
bm25_results = bm25_retriever.invoke(query_bm25)
print(f"검색어: {query_bm25}")
for i, doc in enumerate(bm25_results, 1):
    print(f"  BM25 결과 {i}: {doc.page_content[:150]}...")

# 하이브리드 검색기 (BM25 + 의미 기반)
print("\n[2] 하이브리드 검색기 (BM25 + 벡터 검색)")
hybrid_retriever = EnsembleRetriever(
    retrievers=[bm25_retriever, text_retriever],
    weights=[0.5, 0.5]  # BM25와 벡터 검색에 동일한 가중치
)

query_hybrid = "코스피 현황"
hybrid_results = hybrid_retriever.invoke(query_hybrid)
print(f"검색어: {query_hybrid}")

for i, doc in enumerate(hybrid_results, 1):
    print(f"  결과 {i}: {doc.page_content[:160]}...")
# Out:
# 검색어: 9월 은행 가계대출
#   BM25 결과 1: 본문 list_item...
#   BM25 결과 2: 본문 table...
#   BM25 결과 3: 본문 text...
#
# [2] 하이브리드 검색기 (BM25 + 벡터 검색)
# 검색어: 코스피 현황
#   결과 1: 본문 list_item...
#   결과 2: - □ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - □ 단기시장금리 는 기준금리 인하 기대 약화 , 발행물량 감소 등의 영향 이 엇갈리며 대체로 보합세 *
# * 다만 , 은행채는 MMF 의 투자수요 부...
#   결과 3: 본문 table...
#   결과 4: ￭ 국고채 (3 년 ), 23.12 월 = 3.15. ￭ 국고채 (3 년 ), 24.12 월 = 2.60. ￭ 국고채 (3 년 ), 25.7 월 = 2.46. ￭ 국고채 (3 년 ), 8 월 (A) = 2.43. ￭ 국고채 (3 년 ), 9 월 = 2.58. ￭ 국고채 (3 년 ), 1...
#   결과 5: 본문 text...
#   결과 6: - ▣ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융 안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - ▣ 코스피 는 반도체 업황 호조 및 자본시장 제도 개선에 대한 기대 , 외국인의 대규모 순매수 등으로 사상 최고치를 경신하며 큰 폭 상승
# - ▣ ...
#   결과 7: 은행 가계대출 1), 25.4 월 = 4.7. 은행 가계대출 1), 5 월 = 5.2. 은행 가계대출 1), 6 월 = 6.2. 은행 가계대출 1), 7 월 = 2.7. 은행 가계대출 1), 8 월 = 4.1. 은행 가계대출 1), 9 월 = 2.0. 은행 가계대출 1), 25.9 월말...
#   결과 8: ￭ 은행기업대출 ( 원화 ) 1), 2023.1~9 월 = 67.9. ￭ 은행기업대출 ( 원화 ) 1), 2023.9 월 = 11.3. ￭ 은행기업대출 ( 원화 ) 1), 2024.1~9 월 = 68.5. ￭ 은행기업대출 ( 원화 ) 1), 2024.9 월 = 4.3. ￭ 은행기업대출 ...

# %% [markdown]
# ## 8.3.3 Query construction

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# 1. LLM 초기화
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.0)

# 2. 쿼리 확장 프롬프트 정의
template = """
당신은 검색 쿼리 확장 전문가입니다.
주어진 사용자 질문을 분석하여, 검색 품질을 높일 수 있도록 다음 지침에 따라 3개의 독립적이고 상세한 검색 쿼리를 생성하세요.
지침:
1. 원본 질문의 의도를 최대한 유지하고, 다양한 관점과 관련 용어를 포함하세요.
2. 각 쿼리는 쉼표(,)로 구분하고, 다른 설명이나 텍스트 없이 쿼리 목록만 출력하세요.
사용자 질문: "{question}"
확장 쿼리 목록 (쉼표로 구분):
"""

prompt = ChatPromptTemplate.from_template(template)

# 3. LCEL 체인 구성 (프롬프트 -> LLM 호출 -> 문자열 파서)
expansion_chain = prompt | llm | StrOutputParser()

# 4. 쿼리 확장 실행
user_query = "코스피 상승 이유"
expanded_query = expansion_chain.invoke({"question": user_query})

# 결과 출력
print("확장된 쿼리 (검색엔진에 전달될 내용):")
expanded_queries = [q.strip() for q in expanded_query.split(',') if q.strip()]

for i, query in enumerate(expanded_queries, 1):
    print(f"  {i}. {query}")
# Out:
# 확장된 쿼리 (검색엔진에 전달될 내용):
#   1. 코스피 상승 원인
#   2. 코스피 상승 배경 분석
#   3. 최근 코스피 상승 요인

# %% [markdown]
# ## 8.3.4 HyDE

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.documents import Document as LangChainDocument

# HyDE를 위한 프롬프트 정의
hyde_template = """
다음 질문에 대해 검색 결과로 나타날 수 있는 이상적인 문서의 내용을 상상하여 작성해주세요.
이 문서는 질문에 대한 직접적인 답변을 포함하고 있어야 합니다.
질문: "{question}"
"""
hyde_prompt = ChatPromptTemplate.from_template(hyde_template)

# HyDE 체인 구성 (프롬프트 -> LLM 호출 -> 문자열 파서)
hyde_chain = hyde_prompt | llm | StrOutputParser()

# 가상 문서 생성
user_query = "코스피 상승 이유"
hypothetical_document_content = hyde_chain.invoke({"question": user_query})

print(f"✅ 생성된 가상 문서:\n{hypothetical_document_content[:200]}...\n")

# 가상 문서를 LangChain Document 객체로 변환
hypothetical_document = LangChainDocument(page_content=hypothetical_document_content)

# 가상 문서 임베딩
# 이전에 설정된 embedding_model을 사용합니다.
query_embedding = embedding_model.embed_documents([hypothetical_document.page_content])[0]

print(f"✅ 가상 문서 임베딩 생성 완료 (차원: {len(query_embedding)})")

# 생성된 임베딩을 사용하여 벡터 DB에서 검색 (선택 사항)
# db 객체가 이전 셀에서 생성되었다고 가정합니다.
if 'db' in locals():
    print("\n🔍 생성된 임베딩으로 벡터 DB 검색 테스트...")
    results = db.similarity_search_by_vector(query_embedding, k=3)

    for i, result in enumerate(results[:3], 1):
        print(f"\n[검색 결과 {i}]")
        print(f"  섹션: {result.metadata.get('section', 'N/A')}")
        print(f"  페이지: {result.metadata.get('page', 'N/A')}")
        print(f"  내용: {result.page_content[:150]}...")
else:
    print("\n⚠️ 'db' 벡터 데이터베이스가 정의되지 않아 검색 테스트를 건너뜁니다.")
# Out:
# ✅ 생성된 가상 문서:
# # 코스피 상승 이유
#
# ## 서론
# 코스피(KOSPI)는 한국의 대표적인 주식 시장 지수로, 한국거래소에 상장된 모든 보통주를 포함합니다. 최근 코스피가 상승세를 보이고 있는 이유는 여러 가지 경제적, 정치적, 그리고 글로벌 요인들이 복합적으로 작용하고 있기 때문입니다. 본 문서에서는 코스피 상승의 주요 원인들을 분석해 보겠습니다.
#
# ## 1. 글로벌 경제 ...
#
# ✅ 가상 문서 임베딩 생성 완료 (차원: 1536)
#
# 🔍 생성된 임베딩으로 벡터 DB 검색 테스트...
#
# [검색 결과 1]
#   섹션: 본문
#   페이지: 2
#   내용: - □ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - □ 단기시장금리 는 기준금리 인하 기대 약화 , 발행물량 감소 등의 영향 이 엇갈리며 대체로 보합세 *
# * 다만 , 은행채는 MM...
#
# [검색 결과 2]
#   섹션: 본문
#   페이지: 1
#   내용: - ▣ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융 안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - ▣ 코스피 는 반도체 업황 호조 및 자본시장 제도 개선에 대한 기대 , 외국인의 대규모 순매수 등으로 사상 최고치를 경신하며 큰...
#
# [검색 결과 3]
#   섹션: 본문
#   페이지: 2
#   내용: ￭ 국고채 (3 년 ), 23.12 월 = 3.15. ￭ 국고채 (3 년 ), 24.12 월 = 2.60. ￭ 국고채 (3 년 ), 25.7 월 = 2.46. ￭ 국고채 (3 년 ), 8 월 (A) = 2.43. ￭ 국고채 (3 년 ), 9 월 = 2.58. ￭ 국고채...

# %% [markdown]
# ## 8.3.5 리랭킹

# %%
user_query
# Out:
# '코스피 상승 이유'

# %%
from sentence_transformers import CrossEncoder

# CrossEncoder 모델 로드
# 'cross-encoder/ms-marco-MiniLM-L-6-v2'는 영어 모델이므로, 한국어 리랭킹이 필요하면 적절한 모델로 변경해야 합니다.
# 예: 'jhgan/ko-sroberta-multitask' 또는 한국어에 특화된 다른 모델
# 여기서는 예시로 영어 모델을 사용합니다.
try:
    reranker = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2')
    print("✅ CrossEncoder 모델 로드 완료")

    # 이전 검색 결과 (results 변수)가 있다고 가정하고 리랭킹을 수행합니다.
    # 만약 results 변수가 없다면, 먼저 검색 코드를 실행해야 합니다.
    if 'results' in locals() and results:
        print("\n🔍 검색 결과 리랭킹 중...")
        # reranker.predict는 (query, document) 쌍의 리스트를 입력받아 점수 리스트를 반환합니다.
        scores = reranker.predict([(user_query, doc.page_content) for doc in results]).tolist()

        # 결과와 점수를 튜플로 묶어 점수 기준으로 내림차순 정렬
        reranked_results_with_scores = sorted(zip(results, scores), key=lambda x: x[1], reverse=True)

        print("✅ 리랭킹 완료. 상위 3개 결과:")
        for i, (doc, score) in enumerate(reranked_results_with_scores[:3], 1):
            print(f"\n[리랭크 결과 {i}] 점수: {score:.4f}")
            print(f"  섹션: {doc.metadata.get('section', 'N/A')}")
            print(f"  내용: {doc.page_content[:150]}...")
    elif 'db' in locals():
        print("\n⚠️ 'results' 변수가 없습니다. 먼저 검색 코드를 실행하거나, db에서 검색 후 리랭킹을 수행해야 합니다.")
        print("\n예시: db.similarity_search(user_query, k=10) 등으로 results 변수 채우기")
    else:
         print("\n⚠️ 'results' 변수 및 'db' 벡터 데이터베이스가 정의되지 않아 리랭킹 테스트를 건너뜁니다.")


except Exception as e:
    print(f"리랭킹 모델 로드 또는 실행 중 오류 발생: {e}")
    print("pip install sentence-transformers 를 실행했는지 확인해주세요.")
# Out:
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: cross-encoder/ms-marco-MiniLM-L-6-v2
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ CrossEncoder 모델 로드 완료
#
# 🔍 검색 결과 리랭킹 중...
# ✅ 리랭킹 완료. 상위 3개 결과:
#
# [리랭크 결과 1] 점수: 9.1187
#   섹션: 본문
#   내용: - □ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - □ 단기시장금리 는 기준금리 인하 기대 약화 , 발행물량 감소 등의 영향 이 엇갈리며 대체로 보합세 *
# * 다만 , 은행채는 MM...
#
# [리랭크 결과 2] 점수: 8.9647
#   섹션: 본문
#   내용: - ▣ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융 안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - ▣ 코스피 는 반도체 업황 호조 및 자본시장 제도 개선에 대한 기대 , 외국인의 대규모 순매수 등으로 사상 최고치를 경신하며 큰...
#
# [리랭크 결과 3] 점수: 7.5932
#   섹션: 본문
#   내용: ￭ 국고채 (3 년 ), 23.12 월 = 3.15. ￭ 국고채 (3 년 ), 24.12 월 = 2.60. ￭ 국고채 (3 년 ), 25.7 월 = 2.46. ￭ 국고채 (3 년 ), 8 월 (A) = 2.43. ￭ 국고채 (3 년 ), 9 월 = 2.58. ￭ 국고채...

# %% [markdown]
# ## 8.4 메모리 관리 및 대화 히스토리 처리

# %% [markdown]
# 문서미포함

# %%
from langchain_openai import ChatOpenAI
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

# Modern approach using LCEL instead of the legacy ConversationChain
llm = ChatOpenAI(model="gpt-4o")

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    MessagesPlaceholder(variable_name="history"),
    ("human", "{input}"),
])

chain = prompt | llm

store = {}

def get_session_history(session_id: str) -> BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    return store[session_id]

with_history = RunnableWithMessageHistory(
    chain,
    get_session_history,
    input_messages_key="input",
    history_messages_key="history",
)

config = {"configurable": {"session_id": "test_session"}}

try:
    resp1 = with_history.invoke({"input": "9월 은행대출은 가계대출이 변화가 얼마인가요?"}, config=config)
    print(resp1.content)
    resp2 = with_history.invoke({"input": "그럼 지난 달은 변화가 얼마인가요?"}, config=config)
    print(resp2.content)
except Exception as e:
    print(f"Error: {e}")
# Out:
# 죄송하지만, 현재 10월 2023년까지의 데이터만 가지고 있으며, 실시간 정보를 제공할 수 없는 상태입니다. 9월의 은행 가계대출 변화에 대한 최신 정보를 확인하시려면, 한국은행 또는 관련 금융기관의 공시 자료나 보도 자료를 참조하시기 바랍니다.
# 죄송하지만, 2023년 8월의 구체적인 가계대출 변화 수치를 알고 있지 않습니다. 최신 금융 및 대출 데이터는 종종 중앙은행인 한국은행의 발표 또는 공식 금융 보고서에서 확인할 수 있습니다. 이를 통해 가장 정확하고 최신의 정보를 얻으실 수 있을 것입니다. 한국은행 웹사이트나 금융 관련 뉴스를 참조하시기를 추천드립니다.

# %% [markdown]
# 문서포함

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_classic.chains import create_retrieval_chain
from langchain_classic.chains.combine_documents import create_stuff_documents_chain

# 1. LLM 초기화
llm = ChatOpenAI(model="gpt-4o", temperature=0.0)

# 2. 세션별 메모리 저장소
store = {}

def get_session_history(session_id: str) -> BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    return store[session_id]

# 3. 프롬프트 (대화 히스토리 포함)
prompt = ChatPromptTemplate.from_messages([
    ("system",
     "주어진 문맥(context)을 사용하여 사용자의 질문에 답하세요. "
     "만약 답을 모른다면, 모른다고 정직하게 말하세요.\n\n{context}"),
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{input}"),
])

# 4. 체인 구성
if 'db' in locals():
    retriever = db.as_retriever(search_kwargs={"k": 3})
    combine_docs_chain = create_stuff_documents_chain(llm, prompt)
    rag_chain = create_retrieval_chain(retriever, combine_docs_chain)

    # 5. 메모리 연결
    chain_with_history = RunnableWithMessageHistory(
        rag_chain,
        get_session_history,
        input_messages_key="input",
        history_messages_key="chat_history",
        output_messages_key="answer",
    )

    # --- 첫 번째 질문 ---
    print("--- 첫 번째 질문 ---")
    query1 = "9월 은행 가계대출의 변화가 얼마인가요?"
    response1 = chain_with_history.invoke(
        {"input": query1},
        config={"configurable": {"session_id": "user_1"}}
    )
    print(f"👤 사용자: {query1}")
    print(f"🤖 AI: {response1['answer']}\n")

    # --- 두 번째 질문 (문맥 유지 테스트) ---
    print("--- 두 번째 질문 ---")
    query2 = "그럼 지난 달은 변화가 얼마인가요?"
    response2 = chain_with_history.invoke(
        {"input": query2},
        config={"configurable": {"session_id": "user_1"}}
    )
    print(f"👤 사용자: {query2}")
    print(f"🤖 AI: {response2['answer']}\n")

    # --- 메모리 상태 확인 ---
    print("--- 메모리 상태 확인 ---")
    print(store["user_1"].messages)

else:
    print("Vector DB 'db' not found.")
# Out:
# --- 첫 번째 질문 ---
# 👤 사용자: 9월 은행 가계대출의 변화가 얼마인가요?
# 🤖 AI: 9월 은행 가계대출은 전월에 비해 증가규모가 축소되어, 8월의 +4.1조원에서 9월에는 +2.0조원으로 증가했습니다.
#
# --- 두 번째 질문 ---
# 👤 사용자: 그럼 지난 달은 변화가 얼마인가요?
# 🤖 AI: 지난 8월 은행 가계대출의 변화는 +4.1조원이었습니다.
#
# --- 메모리 상태 확인 ---
# [HumanMessage(content='9월 은행 가계대출의 변화가 얼마인가요?', additional_kwargs={}, response_metadata={}), AIMessage(content='9월 은행 가계대출은 전월에 비해 증가규모가 축소되어, 8월의 +4.1조원에서 9월에는 +2.0조원으로 증가했습니다.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='그럼 지난 달은 변화가 얼마인가요?', additional_kwargs={}, response_metadata={}), AIMessage(content='지난 8월 은행 가계대출의 변화는 +4.1조원이었습니다.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]

# %% [markdown]
# ## 8.5.2 캐싱전략

# %%
! pip install redis
# Out:
# Collecting redis
#   Downloading redis-7.4.0-py3-none-any.whl.metadata (12 kB)
# Downloading redis-7.4.0-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.8/409.8 kB 13.7 MB/s eta 0:00:00
# Installing collected packages: redis
# Successfully installed redis-7.4.0

# %%
from langchain_core.caches import InMemoryCache
from langchain_core.globals import set_llm_cache

set_llm_cache(InMemoryCache()) # InMemoryCache로 설정

print("✅ LLM 캐시가 InMemoryCache로 설정되었습니다.")

# LLM 호출 (캐싱 적용됨)
# 첫 번째 호출은 캐시되지 않습니다.
print("\n--- 첫 번째 LLM 호출 ---")
response1 = llm.invoke("What is RAG optimization?")
print(f"Response 1: {response1.content[:150]}...")

# 동일한 쿼리로 두 번째 호출 시 캐시된 결과를 사용합니다.
print("\n--- 두 번째 LLM 호출 (캐시 사용 예상) ---")
response2 = llm.invoke("What is RAG optimization?")
print(f"Response 2: {response2.content[:150]}...")

print("\n💡 동일한 쿼리에 대해 두 번째 호출이 더 빠르게 완료되면 캐시가 작동한 것입니다.")
# Out:
# ✅ LLM 캐시가 InMemoryCache로 설정되었습니다.
#
# --- 첫 번째 LLM 호출 ---
# Response 1: RAG optimization typically refers to optimizing a system or process using the RAG (Red, Amber, Green) status indicator method. This method is often us...
#
# --- 두 번째 LLM 호출 (캐시 사용 예상) ---
# Response 2: RAG optimization typically refers to optimizing a system or process using the RAG (Red, Amber, Green) status indicator method. This method is often us...
#
# 💡 동일한 쿼리에 대해 두 번째 호출이 더 빠르게 완료되면 캐시가 작동한 것입니다.

# %% [markdown]
# ## 8.5.5 비동기 검색 및 캐싱

# %%
import asyncio
from langchain_core.prompts import ChatPromptTemplate

# 답변 생성을 위한 프롬프트 템플릿 정의
answer_template = """
주어진 문맥 정보를 사용하여 사용자의 질문에 답변하세요.
만약 문맥 정보만으로는 답변하기 어렵다면, 아는 정보 내에서 답변하거나 모른다고 말할 수 있습니다.
불필요하거나 관련 없는 정보는 포함하지 마세요.

문맥 정보:
{context}

사용자 질문:
{question}

답변:
"""
answer_prompt = ChatPromptTemplate.from_template(answer_template)


async def run_rag(query):
    # 1. 문서 검색 (비동기)
    docs_task = retriever.ainvoke(query)

    # 검색과 동시에 다른 작업(예: LLM 초기 호출 등)을 할 수 있지만,
    # 여기서는 검색 결과를 기다린 후 LLM 호출을 진행합니다.
    docs = await docs_task

    # 검색된 문서 내용을 하나의 문자열로 합치기
    context = "\n\n".join([doc.page_content for doc in docs])

    # 2. LLM 호출 (비동기) - 검색 결과를 프롬프트에 포함
    # answer_prompt를 사용하여 문맥과 질문을 포함한 프롬프트 생성
    llm_chain = answer_prompt | llm
    response_task = llm_chain.ainvoke({"context": context, "question": query})

    response = await response_task

    # LLM 응답과 검색된 문서를 함께 반환
    return docs, response.content # LLM 응답 객체에서 내용만 반환

# 예시 실행 (필요하다면 아래 주석을 해제하고 실행하세요)
async def main():
    query = "코스피 상승 이유"
    retrieved_docs, answer = await run_rag(query)
    print(f"질문: {query}")
    print(f"답변: {answer}")
    print("\n--- 사용된 문서 ---")
    for i, doc in enumerate(retrieved_docs):
        print(f"문서 {i+1} (페이지: {doc.metadata.get('page', 'N/A')}): {doc.page_content[:100]}...")

if __name__ == "__main__":
    # retriever와 llm 객체가 이전에 정의되어 있어야 합니다.
    if 'retriever' in locals() and 'llm' in locals():
        await main()
    else:
        print("⚠️ retriever 또는 llm 객체가 정의되지 않았습니다. 이전 셀을 실행해주세요.")
# Out:
# 질문: 코스피 상승 이유
# 답변: 코스피는 반도체 업황 호조 및 자본시장 제도 개선에 대한 기대, 외국인의 대규모 순매수 등으로 인해 사상 최고치를 경신하며 큰 폭으로 상승했습니다.
#
# --- 사용된 문서 ---
# 문서 1 (페이지: 2): - □ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - □ 단기시장금리 는 기준금리 인하 기대 ...
# 문서 2 (페이지: 1): - ▣ 국고채금리 는 좁은 범위 내에서 등락하다가 9 월 하순 이후 금융 안정 리스크 증대 , 외국인 국채선물 순매도 등으로 상당폭 상승
# - ▣ 코스피 는 반도체 업황 호조 및 자...
# 문서 3 (페이지: 2): ￭ 국고채 (3 년 ), 23.12 월 = 3.15. ￭ 국고채 (3 년 ), 24.12 월 = 2.60. ￭ 국고채 (3 년 ), 25.7 월 = 2.46. ￭ 국고채 (3 년 ...
